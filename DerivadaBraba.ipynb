# %%
import sympy
sympy.init_printing()
t, g, v, x0 = sympy.symbols("t, g, v, x0")
x = sympy.Function('x')(t)
x = x0 + v*t - g*t**2/(2)
sympy.diff(x, t) 

sympy.diff(x, t)
# Out:
# -g⋅t + v

# %% [markdown]
# Essa parte
