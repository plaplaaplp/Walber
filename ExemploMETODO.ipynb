# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-1,2,100)

fx1 = np.exp(x)
fx2= 2-x

fig = plt.figure(figsize=(15,15)) 

fig, ax = plt.subplots()
ax.plot(x, fx1, color="cyan", label ="cos(x)") 
ax.plot(x, fx2, color="yellow", label ="x(y)")
ax.legend()

# %%
x=2
dx = 1e-5
def f(x): return  (f(x+dx) - f(x))/dx
def g(x): return x**3
x1 = f(x)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-56-0594fd5070b8> in <module>()
#       3 def f(x): return  (f(x+dx) - f(x))/dx
#       4 def g(x): return x**3
# ----> 5 x1 = f(x)
#
# <ipython-input-56-0594fd5070b8> in f(x)
#       1 x=2
#       2 dx = 1e-5
# ----> 3 def f(x): return  (f(x+dx) - f(x))/dx
#       4 def g(x): return x**3
#       5 x1 = f(x)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-56-0594fd5070b8> in f(x)
#       1 x=2
#       2 dx = 1e-5
# ----> 3 def f(x): return  (f(x+dx) - f(x))/dx
#       4 def g(x): return x**3
#       5 x1 = f(x)
#
# RecursionError: maximum recursion depth exceeded

# %%
def f(x): return np.log(2-x)
#def g1(x): return x-0.5*f(x)  
x=0.5
n=0
N= 20
#x=f(x);x 
while x<=x:
  x = f(x);x 
  n+=1
  #print(f'Iteração número: {n}')
  if n > N:
    break
  print(x)
# Out:
# 0.4054651081081644
# 0.46658208988257394
# 0.42749917207798493
# 0.4526672360928065
# 0.4365326511792381
# 0.44690601430835464
# 0.44024906113229983
# 0.4445261539433108
# 0.44178022336443445
# 0.44354400080915557
# 0.4424114414288555
# 0.4431388294987615
# 0.44267172413736067
# 0.44297170933283375
# 0.44277906267212386
# 0.44290278216074025
# 0.44282333010573655
# 0.4428743545550209
# 0.4428415867347372
# 0.4428626303002355

# %%
def f(x)

# %%
def f(x): return np.log(2-x)
#def g1(x): return x-0.5*f(x)  
x=0.5
n=0
N= 10000
#x=f(x);x 
e = 1e-5
xa = -x
while np.abs(x-xa)>= e :
  xa = x
  x = f(x);x 
  n+=1
  #print(f'Iteração número: {n}')
  if n > N:
    break
  print(x)
# Out:
# 0.4054651081081644
# 0.46658208988257394
# 0.42749917207798493
# 0.4526672360928065
# 0.4365326511792381
# 0.44690601430835464
# 0.44024906113229983
# 0.4445261539433108
# 0.44178022336443445
# 0.44354400080915557
# 0.4424114414288555
# 0.4431388294987615
# 0.44267172413736067
# 0.44297170933283375
# 0.44277906267212386
# 0.44290278216074025
# 0.44282333010573655
# 0.4428743545550209
# 0.4428415867347372
# 0.4428626303002355
# 0.4428491161275525
# 0.44285779494696975

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
class ddx:
    def __init__(self, f, h=1e-6):
        self.f = f
        self.h = float(h)

    def __call__(self, x):
        f = self.f
        h = self.h
        return (f(x+h) - f(x))/h

def g(t): return (t*math.log10(t)-1)
ddg = ddx(g)
t = 5
def gn(t): return t - (g(t)/ddg(t))
x1 = gn(t)
x2 = gn(x1)
x3 = gn(x3)
x4 = gn(x4)
x5 = gn(x4)
x6 = gn(x5)
x7 = gn(x6)
#print("Metodo Newton-Raphson 5 iterações: f(x)xlog(x)-1 = ", x7)





def g(t): return (math.tan(1.5*t)-t)
ddg = ddx(g)
t = 3
def gn(t): return t - (g(t)/ddg(t))

x11 = gn(t)
x22 = gn(x11)
x33 = gn(x22)
x44 = gn(x33)
x55 = gn(x44)
x66 = gn(x55)
x77 = gn(x66)
x88 = gn(77)

x99 = gn(x88)
x100 = gn(x99)
x101 = gn(x100)
x102 = gn(x101)
x103 = gn(x102)
x104 = gn(x103)

print(gn(t))

import matplotlib.pyplot as plt
x = np.linspace(1,3,100)

fx1 = x*np.log10(x)-1
fx2= np.tan(1.5*x)-x

fig = plt.figure(figsize=(15,15)) 

fig, ax = plt.subplots()
ax.plot(x, fx1, color="black", label ="f(x)xlog(x)-1") 
#ax.plot(x, fx2, color="red", label ="f(x)=tan(1.5x) - x")
ax.legend()
fig2 = plt.figure(figsize=(15,15))
fig2, ax2 = plt.subplots()
ax2.plot(x, fx2, color="red", label ="f(x)=tan(1.5x) - x")
# Out:
# 2.9500165864216523

# %%
#METODO MIL
def f(x): return (math.tan(1.5*x)-x)
#def g1(x): return x-0.5*f(x)  
x=0.5
n=0
N= 10000
#x=f(x);x 
e = 1e-5
xa = -x
while np.abs(x-xa)>= e :
  xa = x
  x = f(x);x 
  n+=1
  print(f'Iteração número de f(x)=tan(1.5x) - x: {n}')
  if n > N:
    break
  print(x)
# Out:
# Iteração número de f(x)=tan(1.5x) - x: 1
# 0.4315964599440725
# Iteração número de f(x)=tan(1.5x) - x: 2
# 0.3245051091091449
# Iteração número de f(x)=tan(1.5x) - x: 3
# 0.20472542276125605
# Iteração número de f(x)=tan(1.5x) - x: 4
# 0.11239441363519198
# Iteração número de f(x)=tan(1.5x) - x: 5
# 0.057812879061910766
# Iteração número de f(x)=tan(1.5x) - x: 6
# 0.02912447880663989
# Iteração número de f(x)=tan(1.5x) - x: 7
# 0.014590053098087231
# Iteração número de f(x)=tan(1.5x) - x: 8
# 0.007298521220487443
# Iteração número de f(x)=tan(1.5x) - x: 9
# 0.00364969800942817
# Iteração número de f(x)=tan(1.5x) - x: 10
# 0.0018249036973079684
# Iteração número de f(x)=tan(1.5x) - x: 11
# 0.0009124586857814621
# Iteração número de f(x)=tan(1.5x) - x: 12
# 0.00045623019754895654
# Iteração número de f(x)=tan(1.5x) - x: 13
# 0.0002281152056072968
# Iteração número de f(x)=tan(1.5x) - x: 14
# 0.00011405761615776759
# Iteração número de f(x)=tan(1.5x) - x: 15
# 5.702880974814921e-05
# Iteração número de f(x)=tan(1.5x) - x: 16
# 2.8514405082732798e-05
# Iteração número de f(x)=tan(1.5x) - x: 17
# 1.4257202567448671e-05
# Iteração número de f(x)=tan(1.5x) - x: 18
# 7.1286012869846195e-06
